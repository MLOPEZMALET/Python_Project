# %%
import os
import re
from nltk.tokenize import word_tokenize
text=open('152.txt','r+',encoding='utf8')
txt=text.read()
#txt ="meme tete apres est trés bon acceuil thai et ca c'est genial sœur cœur fois gras l activité after work hummmmm sans faute"
txt=word_tokenize(txt)
for i in range(len(txt)):
    #print(i)
    if txt[i]=="meme" or txt[i]=="Meme" :
        txt[i]="même"
    elif txt[i]=="tete":
        txt[i]="tête"
    elif txt[i]=="hotel":
        txt[i]="hotêl"
    elif txt[i]=="acceuil" or txt[i]=="Acceuil" or txt[i]=="Accueuil":
        txt[i]="accueil"
    elif txt[i]=="tres" or txt[i]=="trés" :
        txt[i]="très"
    elif txt[i]=="Trés" or txt[i]=="Tres":
        txt[i]="Très"
    elif txt[i]=="apres" or txt[i]=="aprés":
        txt[i]="après"
    elif txt[i]=="Apres" or txt[i]=="Aprés":
        txt[i]="Après"
    elif txt[i]=="plutot":
        txt[i]="plutôt"
    elif txt[i]=="presentation":
        txt[i]="présentation"
    elif txt[i]=="cote"or txt[i]=="coté":
        txt[i]="côté"
    elif txt[i]=="etre" or txt[i]=="étre":
        txt[i]="être"
    elif txt[i]=="genial":
        txt[i]="génial"
    elif txt[i]=="interieur":
        txt[i]="intérieur"
    elif txt[i]=="vinegre":
        txt[i]="vinaigre"
    elif txt[i]=="ca":
        txt[i]="ça"
    elif txt[i]=="Ca":
        txt[i]="Ça"
    elif txt[i]=="legumes":
        txt[i]="légumes"
    elif txt[i]=="simpa":
        txt[i]="sympa"
    elif txt[i]=="deception":
        txt[i]="déception"
    elif txt[i]=="reservation":
        txt[i]="réservation"
    elif txt[i]=="etait":
        txt[i]="était"
    elif txt[i]=="delice":
        txt[i]="délice"
    elif txt[i]=="equipe":
        txt[i]="équipe"
    elif txt[i]=="deco":
        txt[i]="décor"
    elif txt[i]=="Deco":
        txt[i]="Décor"
    elif txt[i]=="deplorable":
        txt[i]="déplorable"
    elif txt[i]=="décu"or txt[i]=="décu" or txt[i]=="deçu":
        txt[i]="déçu"
    elif txt[i]=="vegan":
        txt[i]="végan"
    elif txt[i]=="prés":
        txt[i]="près"
    elif txt[i]=="gateau":
        txt[i]="gâteau"
    elif txt[i]=="reussi":
        txt[i]="réussi"
    elif txt[i]=="elegante":
        txt[i]="élègante"
    elif txt[i]=="decouverte":
        txt[i]="découverte"
    elif txt[i]=="vegans":
        txt[i]="végans"
    elif txt[i]=="vegete" or txt[i]=="végete":
        txt[i]="végète"
    elif txt[i]=="ptit":
        txt[i]="petit"
    elif txt[i]=="etoile":
        txt[i]="étoile"
    elif txt[i]=="patisserie" or txt[i]=="Patisserie" :
        txt[i]="pâtisserie"
    elif txt[i]=="dej"or txt[i]=="Dejeuner" or txt[i]=="dejeuner":
        txt[i]="déjeuner"
    elif txt[i]=="tjs":
        txt[i]="toujours"
    elif txt[i]=="ete":
        txt[i]="été"
    elif txt[i]=="sympatique":
        txt[i]="sympathique"
    elif txt[i]=="sympatiques":
        txt[i]="sympathiques"
    elif txt[i]=="soiree":
        txt[i]="soirée"
    elif txt[i]=="deja":
        txt[i]="déjà"
    elif txt[i]=="sympatique":
        txt[i]="sympathique"
    elif txt[i]=="agreable":
        txt[i]="agréable"
    elif txt[i]=="hazard":
        txt[i]="hasard"
    elif txt[i]=="decouvrir":
        txt[i]="découvrir"
    elif txt[i]=="resultat":
        txt[i]="résultat"
    elif txt[i]=="cafe" or txt[i]=="Cafe":
        txt[i]="café"
    elif txt[i]=="autrés":
        txt[i]="autres"
    elif txt[i]=="regal":
        txt[i]="régal"
    elif txt[i]=="regale":
        txt[i]="régale"
    elif txt[i]=="experience":
        txt[i]="expérience"
    elif txt[i]=="exterieur":
        txt[i]="extérieur"
    elif txt[i]=="bemol":
        txt[i]="bémol"
    elif txt[i]=="bcp":
        txt[i]="beaucoup"
    elif txt[i]=="delicieux":
        txt[i]="délicieux"
    elif txt[i]=="delicieuse":
        txt[i]="délicieuse"
    elif txt[i]=="voila":
        txt[i]="voilà"
    elif txt[i]=="ds":
        txt[i]="des"
    elif txt[i]=="etes":
        txt[i]="êtes"
    elif txt[i]=="pr":
        txt[i]="pour"
    elif txt[i]=="seche":
        txt[i]="sèche"
    elif txt[i]=="crepes" or txt[i]=="crèpes":
        txt[i]="crêpes"
    elif txt[i]=="goutu":
        txt[i]="goûtu"
    elif txt[i]=="repond":
        txt[i]="répond"
    elif txt[i]=="probléme" or txt[i]=="probleme":
        txt[i]="problème"
    elif txt[i]=="prealable":
        txt[i]="préalable"
    elif txt[i]=="ecoeurante":
        txt[i]="écouerante"
    elif txt[i]=="pû":
        txt[i]="pu"
    elif txt[i]=="afterwork":
        txt[i]="après travaille,"
    elif txt[i]=="prit":
        txt[i]="pris"
    elif txt[i]=="decevant":
        txt[i]="décevant"
    elif txt[i]=="selection":
        txt[i]="sélection"
    elif txt[i]=="derniere":
        txt[i]="dernière"
    elif txt[i]=="atmosphere":
        txt[i]="atmosphère"
    elif txt[i]=="tradis":
        txt[i]="traditionnelles"
    elif txt[i]=="thai":
        txt[i]="thaï"
    elif txt[i]=="egalement":
        txt[i]="également"
    elif txt[i]=="especes":
        txt[i]="espèces"
    elif txt[i]=="interet":
        txt[i]="intérêt"
    elif txt[i]=="qualite":
        txt[i]="qualité"
    elif txt[i]=="detail":
        txt[i]="détail"
    elif txt[i]=="déssert":
        txt[i]="dessert"
    elif txt[i]=="defaut":
        txt[i]="défaut"
    elif txt[i]=="fois" and txt[i+1]=="gras":
        txt[i]="foie"
    elif txt[i]=="after" and txt[i+1]=="work":
        txt[i]="après"
        txt[i+1]="travail"
    elif txt[i]=="l"and txt[i+1]!="'":
        txt[i]="l'"
    elif txt[i]=="L"and txt[i+1]!="'":
        txt[i]="L'"
    elif txt[i]=="d"and txt[i+1]!="'":
        txt[i]="d'"
    elif txt[i]=="n"and txt[i+1]!="'":
        txt[i]="n'"
    elif txt[i]=="c"and txt[i+1]!="'":
        txt[i]="c'"
    elif txt[i]=="cœur":
        txt[i]='coeur'
    elif txt[i]=="bœuf":
        txt[i]='boeuf'
    elif txt[i]=="œuf":
        txt[i]='oeuf'
    elif txt[i]=="sans"and txt[i+1]=="faute":
        txt[i]="sans-faute"
        txt[i+1]=","
    elif txt[i]=="soit" and txt[i+1]=="disant":
        txt[i]="soi-disant"
        txt[i+1]=","
    elif txt[i]=="amuse" and txt[i+1]=="bouche":
        txt[i]="amuse-bouche"
        txt[i+1]=","
    elif txt[i]=="rendez" and txt[i+1]=="vous":
        txt[i]="rendez-vous"
        txt[i+1]=","
    elif txt[i]=="au"and txt[i+1]=="dessus":
        txt[i]="au-dessus"
        txt[i+1]=","
    elif txt[i]=="Allez" and txt[i+1]=="y":
        txt[i]="Allez-y"
        txt[i+1]=","
    elif txt[i]=="allez" and txt[i+1]=="y":
        txt[i]="allez-y"
        txt[i+1]=","
    elif txt[i]=="un" and txt[i+1]=="menu":
        txt[i]="une"
        txt[i+1]="menue"
    elif txt[i]=="une" and txt[i+1]=="verre":
        txt[i]="un"
    elif txt[i]=="après" and txt[i+1]=="midi":
        txt[i]="aprés-midi"
        txt[i+1]=","
    elif txt[i]=="tout" and txt[i+1]=="a" and txt[i+2]=="fait":
        txt[i+1]="à"
    elif txt[i]=="depuis" and txt[i+1]=="long" and txt[i+2]=="temps":
        txt[i+1]="longtemps"
        txt[i+2]==","
    
#theatre
t=' '.join(txt)

u=open('output19.txt','w',encoding='utf8')
u.write(t)
text.close()
u.close()
